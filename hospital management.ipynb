# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnika2005/SHOPMART/blob/main/hospital%20management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import time
import json
import random

print("===HOSPITAL BIG DATA SYSTEM:5V's ANALYSIS===\n")

#---1. VARIETY:Displaying different data formats---
print("---1. Variety:Handling Diverse Data Formats---")

#Structured(Excel/Database Style)
structured_excel = pd.DataFrame({
    'patient_id':[1001, 1002],
    'age':[45,30],
    'blood_type':['A+','O-']
})

print(f"[STRUCTURED-Excel Style]:\n{structured_excel}\n")

#Semi-Structured(JSON/Log style)
semi_structured_log={
    "timestamp":"2026-02-03T21:45:00Z",
    "event":"Lab_Result_Upload",
    "status":200
    }

print(f"[SEMI-STRUCTURED-JSON Log]:\n{json.dumps(semi_structured_log, indent=2)}\n")

#Unstructured(Media/Files Style)
unstructured_data = "FILES:chest_xray_1001.jpg(Image),cardiac_ultrasound.mp4(Video)"
print(f"[UNSTRUCTURED-Images/Videos]:\n{unstructured_data}\n")

#---2.VOLUME: Aggregating all Hospital/Clinc data---
total_records = 1000000
print(f"---2.Volume:Global Hospital Network---")
print(f"Total Database Volume:{total_records}records collected from all clinics.\n")

#---3.VELOCITY: High-speed test record generation---
print("---3.Velocity:Real-time Patient Test Stream ---")
for i in range(3):
  print(f"Incoming Test Record{i+1}: Generated at high speed...")
  time.sleep(0.3)
print("Stream Processing Complete.\n")

#---4.VERACITY:Accuracy and Trustworrthiness---
print("---4.Veracity:Data Validation---")
raw_data_count = 3
trusted_data_count = 2
print(f"Accuracy Check: Filtered {raw_data_count - trusted_data_count}untrustworthyrecord(s).\n")

#---5.VALUE: Detection and Treatment ---
print("---5.Value:Business/Medical Insight ---")
print("Actionable Result: Early Diease Detection achieved. Treatment costs reduced by 15%.")
# Out:
# ===HOSPITAL BIG DATA SYSTEM:5V's ANALYSIS===
#
# ---1. Variety:Handling Diverse Data Formats---
# [STRUCTURED-Excel Style]:
#    patient_id  age blood_type
# 0        1001   45         A+
# 1        1002   30         O-
#
# [SEMI-STRUCTURED-JSON Log]:
# {
#   "timestamp": "2026-02-03T21:45:00Z",
#   "event": "Lab_Result_Upload",
#   "status": 200
# }
#
# [UNSTRUCTURED-Images/Videos]:
# FILES:chest_xray_1001.jpg(Image),cardiac_ultrasound.mp4(Video)
#
# ---2.Volume:Global Hospital Network---
# Total Database Volume:1000000records collected from all clinics.
#
# ---3.Velocity:Real-time Patient Test Stream ---
# Incoming Test Record1: Generated at high speed...
# Incoming Test Record2: Generated at high speed...
# Incoming Test Record3: Generated at high speed...
# Stream Processing Complete.
#
# ---4.Veracity:Data Validation---
# Accuracy Check: Filtered 1untrustworthyrecord(s).
#
# ---5.Value:Business/Medical Insight ---
# Actionable Result: Early Diease Detection achieved. Treatment costs reduced by 15%.
